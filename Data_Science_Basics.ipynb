# %% [markdown]
# <a href="https://colab.research.google.com/github/Mohit-Duggal/Data_Science_python/blob/main/Data_Science_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **DATA SCIENE START.**

# %%
data = pd.read_csv('https://raw.githubusercontent.com/Mohit-Duggal/Data_Science_python/main/PokemonData.csv')
data.head()
# Out:
#    Num                   Name  Type1   Type2  HP  Attack  Defense  SpAtk  \
# 0    1              Bulbasaur  Grass  Poison  45      49       49     65
# 1    2                Ivysaur  Grass  Poison  60      62       63     80
# 2    3               Venusaur  Grass  Poison  80      82       83    100
# 3    3  VenusaurMega Venusaur  Grass  Poison  80     100      123    122
# 4    4             Charmander   Fire     NaN  39      52       43     60
#
#    SpDef  Speed  Generation  Legendary
# 0     65     45           1      False
# 1     80     60           1      False
# 2    100     80           1      False
# 3    120     80           1      False
# 4     50     65           1      False

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Num         800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type1       800 non-null    object
#  3   Type2       414 non-null    object
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   SpAtk       800 non-null    int64
#  8   SpDef       800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.7+ KB

# %%
data.corr()
# Out:
#                  Num        HP    Attack   Defense     SpAtk     SpDef  \
# Num         1.000000  0.097614  0.102298  0.094786  0.088759  0.085817
# HP          0.097614  1.000000  0.422386  0.239622  0.362380  0.378718
# Attack      0.102298  0.422386  1.000000  0.438687  0.396362  0.263990
# Defense     0.094786  0.239622  0.438687  1.000000  0.223549  0.510747
# SpAtk       0.088759  0.362380  0.396362  0.223549  1.000000  0.506121
# SpDef       0.085817  0.378718  0.263990  0.510747  0.506121  1.000000
# Speed       0.010733  0.175952  0.381240  0.015227  0.473018  0.259133
# Generation  0.982516  0.058683  0.051451  0.042419  0.036437  0.028486
# Legendary   0.153396  0.273620  0.345408  0.246377  0.448907  0.363937
#
#                Speed  Generation  Legendary
# Num         0.010733    0.982516   0.153396
# HP          0.175952    0.058683   0.273620
# Attack      0.381240    0.051451   0.345408
# Defense     0.015227    0.042419   0.246377
# ...

# %%
f,ax = plt.subplots(figsize=(20, 20))
sns.heatmap(data.corr(), annot=True, linewidths=.5 , fmt= '.1f' ,ax=ax)
plt.show()

# %%
data.head(10)
# Out:
#    Num                       Name  Type1   Type2  HP  Attack  Defense  SpAtk  \
# 0    1                  Bulbasaur  Grass  Poison  45      49       49     65
# 1    2                    Ivysaur  Grass  Poison  60      62       63     80
# 2    3                   Venusaur  Grass  Poison  80      82       83    100
# 3    3      VenusaurMega Venusaur  Grass  Poison  80     100      123    122
# 4    4                 Charmander   Fire     NaN  39      52       43     60
# 5    5                 Charmeleon   Fire     NaN  58      64       58     80
# 6    6                  Charizard   Fire  Flying  78      84       78    109
# 7    6  CharizardMega Charizard X   Fire  Dragon  78     130      111    130
# 8    6  CharizardMega Charizard Y   Fire  Flying  78     104       78    159
# 9    7                   Squirtle  Water     NaN  44      48       65     50
#
#    SpDef  Speed  Generation  Legendary
# 0     65     45           1      False
# 1     80     60           1      False
# ...

# %%
data.columns
# Out:
# Index(['Num', 'Name', 'Type1', 'Type2', 'HP', 'Attack', 'Defense', 'SpAtk',
#        'SpDef', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %% [markdown]
# ***MATPLOTLIB***

# %%
data.Speed.plot(kind= 'line', color = 'g',label = 'Speed' , linewidth=1,alpha= 0.5, grid = True,linestyle = ':')
data.Defense.plot(color = 'r',label = 'Defence', linewidth=1, alpha = 0.5 , grid =True , linestyle= '-.')
plt.legend(loc='upper right')
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title('Line Plot')
plt.show()

# %%
data.plot(kind = 'scatter' , x='Attack', y='Defense' , alpha=0.3,color='blue')
plt.title('Attack Defense Scatter Plot')
# Out:
# Text(0.5, 1.0, 'Attack Defense Scatter Plot')

# %%
data.plot(kind='scatter', x='SpDef', y='SpAtk' , alpha= 0.5 , color="red")
plt.title('Power')
# Out:
# Text(0.5, 1.0, 'Power')

# %%
data.Speed.plot(kind= 'hist',bins=50,figsize = (6,6))
plt.show()

# %%
data.Speed.plot(kind = 'hist',bins = 50)
plt.clf()

# %%
dict = {'india': 'delhi','russia': 'mosko'}
print(dict.keys())
print(dict.values())
# Out:
# dict_keys(['india', 'russia'])
# dict_values(['delhi', 'mosko'])

# %%
dict['india'] = "kolkata"
print(dict)
dict['russia'] = "moskoa"
print(dict)
del dict['russia']
print(dict)
print('india' in dict)
dict.clear()
print(dict)
# Out:
# {'india': 'kolkata', 'russia': 'mosko'}
# {'india': 'kolkata', 'russia': 'moskoa'}
# {'india': 'kolkata'}
# True
# {}

# %%
print(dict)
# Out:
# {}

# %% [markdown]
# PANDA

# %%
data = pd.read_csv('https://raw.githubusercontent.com/Mohit-Duggal/Data_Science_python/main/PokemonData.csv')
data.head()
# Out:
#    Num                   Name  Type1   Type2  HP  Attack  Defense  SpAtk  \
# 0    1              Bulbasaur  Grass  Poison  45      49       49     65
# 1    2                Ivysaur  Grass  Poison  60      62       63     80
# 2    3               Venusaur  Grass  Poison  80      82       83    100
# 3    3  VenusaurMega Venusaur  Grass  Poison  80     100      123    122
# 4    4             Charmander   Fire     NaN  39      52       43     60
#
#    SpDef  Speed  Generation  Legendary
# 0     65     45           1      False
# 1     80     60           1      False
# 2    100     80           1      False
# 3    120     80           1      False
# 4     50     65           1      False

# %%
series = data['Defense']
print(type(series))
data_frame = data[['Defense']]
print(type(data_frame))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>

# %%
x = data['Defense']>200
data[x]
# Out:
#      Num                 Name  Type1   Type2  HP  Attack  Defense  SpAtk  \
# 224  208  SteelixMega Steelix  Steel  Ground  75     125      230     55
# 230  213              Shuckle    Bug    Rock  20      10      230     10
# 333  306    AggronMega Aggron  Steel     NaN  70     140      230     60
#
#      SpDef  Speed  Generation  Legendary
# 224     95     30           2      False
# 230    230      5           2      False
# 333     80     50           3      False

# %%
data[np.logical_and(data['Defense']>200 ,data['Attack']>100)]
# Out:
#      Num                 Name  Type1   Type2  HP  Attack  Defense  SpAtk  \
# 224  208  SteelixMega Steelix  Steel  Ground  75     125      230     55
# 333  306    AggronMega Aggron  Steel     NaN  70     140      230     60
#
#      SpDef  Speed  Generation  Legendary
# 224     95     30           2      False
# 333     80     50           3      False

# %%
data[(data['Defense']>200) & (data['Attack']>100)]
# Out:
#      Num                 Name  Type1   Type2  HP  Attack  Defense  SpAtk  \
# 224  208  SteelixMega Steelix  Steel  Ground  75     125      230     55
# 333  306    AggronMega Aggron  Steel     NaN  70     140      230     60
#
#      SpDef  Speed  Generation  Legendary
# 224     95     30           2      False
# 333     80     50           3      False

# %%
i = 0
while i != 6 :
    print('i is: ',i)
    i +=1
print(i, 'is equal to 5')
# Out:
# i is:  0
# i is:  1
# i is:  2
# i is:  3
# i is:  4
# i is:  5
# 6 is equal to 5

# %%
list = [1,2,3,4,5]
for i in list:
    print('i  is ',i)
print(' ')

for index, value in enumerate(list):
    print(index," : ",value)
print(' ')

dict = {'india':'Delhi','russia':'mahsco'}
for key,value in dict.items():
    print(key,':',value)
print(' ')

for index , value in data[['Attack']] [90:100].iterrows():
    print(index," : ",value)
# Out:
# i  is  1
# i  is  2
# i  is  3
# i  is  4
# i  is  5
#
# 0  :  1
# 1  :  2
# 2  :  3
# 3  :  4
# 4  :  5
#
# india : Delhi
# russia : mahsco
#
# 90  :  Attack    65
# Name: 90, dtype: int64
# 91  :  Attack    85
# Name: 91, dtype: int64
# 92  :  Attack    110
# Name: 92, dtype: int64
# 93  :  Attack    45
# Name: 93, dtype: int64
# 94  :  Attack    70
# Name: 94, dtype: int64
# 95  :  Attack    80
# Name: 95, dtype: int64
# 96  :  Attack    105
# Name: 96, dtype: int64
# 97  :  Attack    65
# Name: 97, dtype: int64
# 98  :  Attack    95
# Name: 98, dtype: int64
# 99  :  Attack    35
# Name: 99, dtype: int64

# %% [markdown]
# > **TOOLBOX**

# %%
def tuple_ex():
    t = (1,2,3)
    return t
a,b,c = tuple_ex()
print(a,b,c)
# Out:
# 1 2 3

# %%
x = 59
def f():
    y = 2 * x
    return y
print(f())
# Out:
# 118

# %%
import builtins
dir(builtins)
# Out:
# ['ArithmeticError',
#  'AssertionError',
#  'AttributeError',
#  'BaseException',
#  'BlockingIOError',
#  'BrokenPipeError',
#  'BufferError',
#  'BytesWarning',
#  'ChildProcessError',
#  'ConnectionAbortedError',
#  'ConnectionError',
#  'ConnectionRefusedError',
#  'ConnectionResetError',
#  'DeprecationWarning',
#  'EOFError',
#  'Ellipsis',
#  'EnvironmentError',
#  'Exception',
#  'False',
#  'FileExistsError',
#  'FileNotFoundError',
#  'FloatingPointError',
#  'FutureWarning',
#  'GeneratorExit',
#  'IOError',
#  'ImportError',
#  'ImportWarning',
#  'IndentationError',
#  'IndexError',
#  'InterruptedError',
#  'IsADirectoryError',
#  'KeyError',
#  'KeyboardInterrupt',
#  'LookupError',
#  'MemoryError',
#  'ModuleNotFoundError',
#  'NameError',
#  'None',
#  'NotADirectoryError',
#  'NotImplemented',
#  'NotImplementedError',
#  'OSError',
#  'OverflowError',
#  'PendingDeprecationWarning',
#  'PermissionError',
#  'ProcessLookupError',
#  'RecursionError',
# ...

# %%
def square():
    
    def add():
        x = 2
        y = 4
        z = x + y
        return z
    return add()**2
print(square())
# Out:
# 36

# %%
def f(a ,b=2,c=5):
    y = a+b+c
    return y 
print(f(5))
print(f(2,56,66))
# Out:
# 12
# 124

# %%
def f(*arg):
    for i in arg:
        print(i)
f(1)
print(" ")
f('a','b',3)

print(" ")

def f(**kwarg):
    for key,val in kwarg.items():
        print(key," : ",val)
f(country = 'india' , captial = 'delhi' , population = 1200000000)
# Out:
# 1
#
# a
# b
# 3
#
# country  :  india
# captial  :  delhi
# population  :  1200000000

# %% [markdown]
# LAMBDA FUNCTION

# %%
sqaure = lambda x: x**2
print(sqaure(4))
tot = lambda x,y,z : x+y+z
print(tot(2,56,6))
# Out:
# 16
# 64

# %% [markdown]
# ANONYMOUS FUNCTION

# %%
number_list = [1,2,3]
y = map(lambda x:x**2,number_list)
print(y)

# %% [markdown]
# ITERATORS

# %%
name = "mohit duggal"
it = iter(name)
print(next(it))
print(*it)
# Out:
# m
# o h i t   d u g g a l

# %% [markdown]
# ZIP(): ZIP LISTS

# %%
list1 = [1,2,3,4]
list2 = [5,6,7,8]
z = zip(list1,list2)
print(z)
#z_list = list(z)
#print(z_list)

# %%
#un_zip = zip(*z_list)
#un_list1,un_list2 = list(un_zip)
#print(un_list1)
#print(un_list2)
#print(type(un_list2))

# %%
num1 = [1,2,3]
num2 = [i+1 for i in num1]
print(num2)
# Out:
# [2, 3, 4]

# %%
threshold = sum(data.Speed)/len(data.Speed)
data["Speed_level"] = ["High" if i>threshold else "low" for i in data.Speed]
data.loc[:10,["Speed_level","Speed"]]
# Out:
#    Speed_level  Speed
# 0          low     45
# 1          low     60
# 2         High     80
# 3         High     80
# 4          low     65
# 5         High     80
# 6         High    100
# 7         High    100
# 8         High    100
# 9          low     43
# 10         low     58

# %% [markdown]
# **CLEANING DATA**

# %%
data = pd.read_csv('https://raw.githubusercontent.com/Mohit-Duggal/Data_Science_python/main/PokemonData.csv')
data.head()
# Out:
#    Num                   Name  Type1   Type2  HP  Attack  Defense  SpAtk  \
# 0    1              Bulbasaur  Grass  Poison  45      49       49     65
# 1    2                Ivysaur  Grass  Poison  60      62       63     80
# 2    3               Venusaur  Grass  Poison  80      82       83    100
# 3    3  VenusaurMega Venusaur  Grass  Poison  80     100      123    122
# 4    4             Charmander   Fire     NaN  39      52       43     60
#
#    SpDef  Speed  Generation  Legendary
# 0     65     45           1      False
# 1     80     60           1      False
# 2    100     80           1      False
# 3    120     80           1      False
# 4     50     65           1      False

# %%
data.tail()
# Out:
#      Num                 Name    Type1  Type2  HP  Attack  Defense  SpAtk  \
# 795  719              Diancie     Rock  Fairy  50     100      150    100
# 796  719  DiancieMega Diancie     Rock  Fairy  50     160      110    160
# 797  720  HoopaHoopa Confined  Psychic  Ghost  80     110       60    150
# 798  720   HoopaHoopa Unbound  Psychic   Dark  80     160       60    170
# 799  721            Volcanion     Fire  Water  80     110      120    130
#
#      SpDef  Speed  Generation  Legendary
# 795    150     50           6       True
# 796    110    110           6       True
# 797    130     70           6       True
# 798    130     80           6       True
# 799     90     70           6       True

# %%
data.columns
# Out:
# Index(['Num', 'Name', 'Type1', 'Type2', 'HP', 'Attack', 'Defense', 'SpAtk',
#        'SpDef', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
data.shape
# Out:
# (800, 12)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Num         800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type1       800 non-null    object
#  3   Type2       414 non-null    object
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   SpAtk       800 non-null    int64
#  8   SpDef       800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.7+ KB

# %%
print(data['Type1'].value_counts(dropna=False))
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Dragon       32
# Ground       32
# Ghost        32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type1, dtype: int64

# %%
1,2,3,4,224
# Out:
# (1, 2, 3, 4, 224)

# %%
data.describe()
# Out:
#               Num          HP      Attack     Defense       SpAtk       SpDef  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
f,ax = plt.subplots(figsize=(18, 18))
sns.heatmap(data.describe(), annot=True, linewidths=0.5 , fmt= '.1f' ,ax=ax)
plt.show()

# %%
data.boxplot(column='Attack',by = 'Legendary')
# Out:
# <AxesSubplot:title={'center':'Attack'}, xlabel='Legendary'>

# %%
data_new = data.head()
data_new
# Out:
#    Num                   Name  Type1   Type2  HP  Attack  Defense  SpAtk  \
# 0    1              Bulbasaur  Grass  Poison  45      49       49     65
# 1    2                Ivysaur  Grass  Poison  60      62       63     80
# 2    3               Venusaur  Grass  Poison  80      82       83    100
# 3    3  VenusaurMega Venusaur  Grass  Poison  80     100      123    122
# 4    4             Charmander   Fire     NaN  39      52       43     60
#
#    SpDef  Speed  Generation  Legendary
# 0     65     45           1      False
# 1     80     60           1      False
# 2    100     80           1      False
# 3    120     80           1      False
# 4     50     65           1      False

# %%
melting = pd.melt(frame=data_new,id_vars='Name', value_vars=['Attack','Defense'])
melting
# Out:
#                     Name variable  value
# 0              Bulbasaur   Attack     49
# 1                Ivysaur   Attack     62
# 2               Venusaur   Attack     82
# 3  VenusaurMega Venusaur   Attack    100
# 4             Charmander   Attack     52
# 5              Bulbasaur  Defense     49
# 6                Ivysaur  Defense     63
# 7               Venusaur  Defense     83
# 8  VenusaurMega Venusaur  Defense    123
# 9             Charmander  Defense     43

# %%
melting.pivot(index='Name',columns='variable',values='value')
# Out:
# variable               Attack  Defense
# Name
# Bulbasaur                  49       49
# Charmander                 52       43
# Ivysaur                    62       63
# Venusaur                   82       83
# VenusaurMega Venusaur     100      123

# %%
data1 = data.head()
data2 = data.tail()
data_conc = pd.concat([data1,data2],axis = 0,ignore_index = True)
data_conc
# Out:
#    Num                   Name    Type1   Type2  HP  Attack  Defense  SpAtk  \
# 0    1              Bulbasaur    Grass  Poison  45      49       49     65
# 1    2                Ivysaur    Grass  Poison  60      62       63     80
# 2    3               Venusaur    Grass  Poison  80      82       83    100
# 3    3  VenusaurMega Venusaur    Grass  Poison  80     100      123    122
# 4    4             Charmander     Fire     NaN  39      52       43     60
# 5  719                Diancie     Rock   Fairy  50     100      150    100
# 6  719    DiancieMega Diancie     Rock   Fairy  50     160      110    160
# 7  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60    150
# 8  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60    170
# 9  721              Volcanion     Fire   Water  80     110      120    130
#
#    SpDef  Speed  Generation  Legendary
# 0     65     45           1      False
# 1     80     60           1      False
# ...

# %%
data1 = data['Attack'].head()
data2 = data['Defense'].head()
data_conc_col = pd.concat([data1,data2],axis = 1)
data_conc_col
# Out:
#    Attack  Defense
# 0      49       49
# 1      62       63
# 2      82       83
# 3     100      123
# 4      52       43

# %%
data_concat = pd.concat([data_conc,data_conc_col],axis=1)
data_concat
# Out:
#    Num                   Name    Type1   Type2  HP  Attack  Defense  SpAtk  \
# 0    1              Bulbasaur    Grass  Poison  45      49       49     65
# 1    2                Ivysaur    Grass  Poison  60      62       63     80
# 2    3               Venusaur    Grass  Poison  80      82       83    100
# 3    3  VenusaurMega Venusaur    Grass  Poison  80     100      123    122
# 4    4             Charmander     Fire     NaN  39      52       43     60
# 5  719                Diancie     Rock   Fairy  50     100      150    100
# 6  719    DiancieMega Diancie     Rock   Fairy  50     160      110    160
# 7  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60    150
# 8  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60    170
# 9  721              Volcanion     Fire   Water  80     110      120    130
#
#    SpDef  Speed  Generation  Legendary  Attack  Defense
# 0     65     45           1      False    49.0     49.0
# ...

# %% [markdown]
# DATA TYPES

# %%
data.dtypes
# Out:
# Num            int64
# Name          object
# Type1         object
# Type2         object
# HP             int64
# Attack         int64
# Defense        int64
# SpAtk          int64
# SpDef          int64
# Speed          int64
# Generation     int64
# Legendary       bool
# dtype: object

# %%
data['Type1']= data['Type1'].astype('category')
data['Speed']=data['Speed'].astype('float')
data.dtypes
# Out:
# Num              int64
# Name            object
# Type1         category
# Type2           object
# HP               int64
# Attack           int64
# Defense          int64
# SpAtk            int64
# SpDef            int64
# Speed          float64
# Generation       int64
# Legendary         bool
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Num         800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type1       800 non-null    category
#  3   Type2       414 non-null    object
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   SpAtk       800 non-null    int64
#  8   SpDef       800 non-null    int64
#  9   Speed       800 non-null    float64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), category(1), float64(1), int64(7), object(2)
# memory usage: 64.9+ KB

# %%
data["Type2"].value_counts(dropna=False)
# Out:
# NaN         386
# Flying       97
# Ground       35
# Poison       34
# Psychic      33
# Fighting     26
# Grass        25
# Fairy        23
# Steel        22
# Dark         20
# Dragon       18
# Ice          14
# Rock         14
# Water        14
# Ghost        14
# Fire         12
# Electric      6
# Normal        4
# Bug           3
# Name: Type2, dtype: int64

# %%
data1 = data
data1['Type2'].dropna(inplace=True)
data1.head()
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Num         800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type1       800 non-null    category
#  3   Type2       414 non-null    object
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   SpAtk       800 non-null    int64
#  8   SpDef       800 non-null    int64
#  9   Speed       800 non-null    float64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), category(1), float64(1), int64(7), object(2)
# memory usage: 64.9+ KB

# %%
assert 1==1
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Num         800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type1       800 non-null    category
#  3   Type2       414 non-null    object
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   SpAtk       800 non-null    int64
#  8   SpDef       800 non-null    int64
#  9   Speed       800 non-null    float64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), category(1), float64(1), int64(7), object(2)
# memory usage: 64.9+ KB

# %%
data['Type2'].notnull().all()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Num         800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type1       800 non-null    category
#  3   Type2       414 non-null    object
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   SpAtk       800 non-null    int64
#  8   SpDef       800 non-null    int64
#  9   Speed       800 non-null    float64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), category(1), float64(1), int64(7), object(2)
# memory usage: 64.9+ KB

# %%
data['Type2'].fillna('empty',inplace = True)

# %%
assert data['Type2'].notnull().all()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Num         800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type1       800 non-null    category
#  3   Type2       800 non-null    object
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   SpAtk       800 non-null    int64
#  8   SpDef       800 non-null    int64
#  9   Speed       800 non-null    float64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), category(1), float64(1), int64(7), object(2)
# memory usage: 64.9+ KB

# %% [markdown]
# **PANDAS FOUNDATION**

# %%
country= ["Spain","France"]
population = ["11","12"]
list_lable = ["country","population"]
list_col = [country,population]
zipped = zip(list_lable,list_col)
data_dict = zipped
df=pd.DataFrame(data_dict)
df
# Out:
#             0                1
# 0     country  [Spain, France]
# 1  population         [11, 12]

# %%
df = data.head()
df
# Out:
#    Num                   Name  Type1   Type2  HP  Attack  Defense  SpAtk  \
# 0    1              Bulbasaur  Grass  Poison  45      49       49     65
# 1    2                Ivysaur  Grass  Poison  60      62       63     80
# 2    3               Venusaur  Grass  Poison  80      82       83    100
# 3    3  VenusaurMega Venusaur  Grass  Poison  80     100      123    122
# 4    4             Charmander   Fire   empty  39      52       43     60
#
#    SpDef  Speed  Generation  Legendary
# 0     65   45.0           1      False
# 1     80   60.0           1      False
# 2    100   80.0           1      False
# 3    120   80.0           1      False
# 4     50   65.0           1      False

# %%
df["protection"]=["true" if i>=100 else "false" for i in df.Attack]
df.loc[: ,["Attack","protection"]]
# Out:
# <ipython-input-67-6756ce7e9536>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["protection"]=["true" if i>=100 else "false" for i in df.Attack]
#    Attack protection
# 0      49      false
# 1      62      false
# 2      82      false
# 3     100       true
# 4      52      false

# %%
df["income"] = 0
df
# Out:
# <ipython-input-68-93e749cfb571>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["income"] = 0
#    Num                   Name  Type1   Type2  HP  Attack  Defense  SpAtk  \
# 0    1              Bulbasaur  Grass  Poison  45      49       49     65
# 1    2                Ivysaur  Grass  Poison  60      62       63     80
# 2    3               Venusaur  Grass  Poison  80      82       83    100
# 3    3  VenusaurMega Venusaur  Grass  Poison  80     100      123    122
# 4    4             Charmander   Fire   empty  39      52       43     60
#
#    SpDef  Speed  Generation  Legendary protection  income
# 0     65   45.0           1      False      false       0
# 1     80   60.0           1      False      false       0
# ...

# %%
data1 = data.loc[:,["Attack","Defense","Speed"]]
data1.plot()
# Out:
# <AxesSubplot:>

# %%
data1.plot(subplots=True)
plt.show()

# %%
data1.plot(kind = "scatter",x="Attack",y = "Defense",alpha = 0.5,color = 'red')
plt.show()

# %%
data1.plot(kind="hist",y="Defense",bins=50,range=(0,250))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
fig, axes = plt.subplots(nrows=2,ncols=1)
data1.plot(kind = "hist",y="Defense",bins=50,range=(0,250),density=True,ax=axes[0])
data1.plot(kind = "hist",y="Defense",bins=50,range=(0,250),density=True,ax=axes[1],cumulative=True)
plt.savefig('graph.png')
plt
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.9/dist-packages/matplotlib/pyplot.py'>

# %% [markdown]
# **INDEXING PANDAS TIME SERIES**

# %%
time_list = ["2005-03-04","2005-04-07"]
print(type(time_list[1]))
datatime_object = pd.to_datetime(time_list)
print(type(datatime_object))
# Out:
# <class 'str'>
# <class 'pandas.core.indexes.datetimes.DatetimeIndex'>

# %%
data2= data.head()
date_list = ["1992-01-10","1992-02-10","1992-03-10","1993-03-15","1993-03-16"]
datatime_object = pd.to_datetime(date_list)
data2["date"] = datatime_object
data2 = data2.set_index("date")
data2
# Out:
# <ipython-input-75-8b74c1d31a9b>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2["date"] = datatime_object
#             Num                   Name  Type1   Type2  HP  Attack  Defense  \
# date
# 1992-01-10    1              Bulbasaur  Grass  Poison  45      49       49
# 1992-02-10    2                Ivysaur  Grass  Poison  60      62       63
# 1992-03-10    3               Venusaur  Grass  Poison  80      82       83
# 1993-03-15    3  VenusaurMega Venusaur  Grass  Poison  80     100      123
# 1993-03-16    4             Charmander   Fire   empty  39      52       43
#
#             SpAtk  SpDef  Speed  Generation  Legendary
# date
# 1992-01-10     65     65   45.0           1      False
# ...

# %%
print(data2.loc["1993-03-16"])
print(data2.loc["1992-03-10":"1993-03-16"])
# Out:
# Num                    4
# Name          Charmander
# Type1               Fire
# Type2              empty
# HP                    39
# Attack                52
# Defense               43
# SpAtk                 60
# SpDef                 50
# Speed               65.0
# Generation             1
# Legendary          False
# Name: 1993-03-16 00:00:00, dtype: object
#             Num                   Name  Type1   Type2  HP  Attack  Defense  \
# date
# 1992-03-10    3               Venusaur  Grass  Poison  80      82       83
# 1993-03-15    3  VenusaurMega Venusaur  Grass  Poison  80     100      123
# 1993-03-16    4             Charmander   Fire   empty  39      52       43
#
#             SpAtk  SpDef  Speed  Generation  Legendary
# date
# 1992-03-10    100    100   80.0           1      False
# 1993-03-15    122    120   80.0           1      False
# 1993-03-16     60     50   65.0           1      False

# %% [markdown]
# **RESAMPLING PANDAS TIME SERIES**

# %%
data2.resample("A").mean()
# Out:
#             Num         HP     Attack  Defense      SpAtk      SpDef  \
# date
# 1992-12-31  2.0  61.666667  64.333333     65.0  81.666667  81.666667
# 1993-12-31  3.5  59.500000  76.000000     83.0  91.000000  85.000000
#
#                 Speed  Generation  Legendary
# date
# 1992-12-31  61.666667         1.0        0.0
# 1993-12-31  72.500000         1.0        0.0

# %%
data2.resample("M").mean()
# Out:
#             Num    HP  Attack  Defense  SpAtk  SpDef  Speed  Generation  \
# date
# 1992-01-31  1.0  45.0    49.0     49.0   65.0   65.0   45.0         1.0
# 1992-02-29  2.0  60.0    62.0     63.0   80.0   80.0   60.0         1.0
# 1992-03-31  3.0  80.0    82.0     83.0  100.0  100.0   80.0         1.0
# 1992-04-30  NaN   NaN     NaN      NaN    NaN    NaN    NaN         NaN
# 1992-05-31  NaN   NaN     NaN      NaN    NaN    NaN    NaN         NaN
# 1992-06-30  NaN   NaN     NaN      NaN    NaN    NaN    NaN         NaN
# 1992-07-31  NaN   NaN     NaN      NaN    NaN    NaN    NaN         NaN
# 1992-08-31  NaN   NaN     NaN      NaN    NaN    NaN    NaN         NaN
# 1992-09-30  NaN   NaN     NaN      NaN    NaN    NaN    NaN         NaN
# 1992-10-31  NaN   NaN     NaN      NaN    NaN    NaN    NaN         NaN
# 1992-11-30  NaN   NaN     NaN      NaN    NaN    NaN    NaN         NaN
# 1992-12-31  NaN   NaN     NaN      NaN    NaN    NaN    NaN         NaN
# ...

# %%
data2.resample("M").first().interpolate("ffill")
# Out:
#             Num                   Name  Type1   Type2    HP  Attack  Defense  \
# date
# 1992-01-31  1.0              Bulbasaur  Grass  Poison  45.0    49.0     49.0
# 1992-02-29  2.0                Ivysaur  Grass  Poison  60.0    62.0     63.0
# 1992-03-31  3.0               Venusaur  Grass  Poison  80.0    82.0     83.0
# 1992-04-30  3.0               Venusaur  Grass  Poison  80.0    82.0     83.0
# 1992-05-31  3.0               Venusaur  Grass  Poison  80.0    82.0     83.0
# 1992-06-30  3.0               Venusaur  Grass  Poison  80.0    82.0     83.0
# 1992-07-31  3.0               Venusaur  Grass  Poison  80.0    82.0     83.0
# 1992-08-31  3.0               Venusaur  Grass  Poison  80.0    82.0     83.0
# 1992-09-30  3.0               Venusaur  Grass  Poison  80.0    82.0     83.0
# 1992-10-31  3.0               Venusaur  Grass  Poison  80.0    82.0     83.0
# 1992-11-30  3.0               Venusaur  Grass  Poison  80.0    82.0     83.0
# ...
